# %%
from PIL import Image
import pandas as pd
from pytesseract import Output
from sys import platform
from pathlib import Path
import pytesseract
import cv2


#  Module global variables.
if platform == "win32":
    pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"
last_index = 0
tokens = []


def resize_image(image, size):
    """Image interpolation function"""

    # Output image dimensions calculation.
    multiplier = size / image.shape[0]
    width = int(image.shape[1] * multiplier)
    height = int(image.shape[0] * multiplier)
    shape = (width, height)

    #  Image resizing.
    resized_image = cv2.resize(image, shape, interpolation=cv2.INTER_CUBIC)
    return resized_image, multiplier


def prepare_image(img_path, size):
    """Function of image preparation before passing to recognition."""
    image = cv2.imread(img_path)
    #  Image resize and getting resize multiplier(how much bigger resized image than original).
    resized_image, multiplier = resize_image(image, size)
    
    #  Reverting image channelf before passing to recognition.
    converted_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB) #  Image channels reversion.
    return image, resized_image, multiplier, converted_image


def recognize_image(cv2_image, config, lang):
    """
    Function getting recognized text from an image

    :img_path: - A path to an image;
    :config: - a string config for tesseract;
    :lang: - language of recognition;

    Returns dataframe with ocr data(including coords, word text and confidence).
    """
    
    #  Ocr data extraction.
    ocr_data = pytesseract.image_to_data(cv2_image, lang=lang, output_type=Output.DATAFRAME, config=config)
    
    return ocr_data


def filter_ocr_data(ocr_data):
    """Function of tesseract output preparation"""

    cols = ['text', 'left', 'top', 'width', 'height', 'conf']

    #  Zero confidence entries deletion.
    confident_ocr_data = ocr_data[ocr_data.conf != -1]

    #  Unused columns removal.
    cleared_ocr_data = confident_ocr_data[cols]
    
    cleared_ocr_data.reset_index(drop=True, inplace=True)

    return cleared_ocr_data


def process_text(prepared_ocr_data, concatenation_sep):
    """
    Function processing text from recognized image.
    
    :prepared_ocr_data: - prepared dataframe of data from recognition;
    :concatenation_sep: - separator to be used in strings concatenaton.
    
    Returns dataframe with text info and concatenated text itself.
    """

    def _calc_span(row, sep):
        """
        Function calculating span for a word in dataframe.
        Requires access to a global var last_index.
        
        :sep: - concatenation separator;
        
        Returns span tupple(start index, stop index).
        """
        global last_index
        
        word_len = len(row["text"])
        
        span = tuple([last_index, last_index + word_len])

        #  Adding word len and sep len to a accumulation variable.
        last_index += word_len + len(sep)
        return span

    global last_index
    
    #  Counting span column using concatenation separator.
    span_col = prepared_ocr_data.apply(lambda r: _calc_span(r, concatenation_sep), axis=1)

    #  Adding new column to a dataframe.
    span_df = prepared_ocr_data.assign(span=span_col)

    #  Removing unused columns.
    text_df = span_df.drop(columns=["conf", "left", "top", "width", "height"])
    
    concatenated_text = concatenation_sep.join(text_df['text'])
    
    last_index = 0
    return concatenated_text, text_df


def process_layout(prepared_ocr_data):
    """
    Function processing coordinates of extracted text.
    
    :prepared_ocr_data: - prepared dataframe of data from recognition.
    
    Returns coords df.
    """
    
    layout_df = prepared_ocr_data.drop(columns=["conf"])
    
    return layout_df


def build_result(merged_df, extracted_text, image_shape):
    """Function preparing final result."""

    def _create_token(row):
        """
        Function creates token from a merged dataframe row and
        appends it to global tokens variable
        """
        global tokens
        token_dict = {
            "text": row["text"],
            "position": {
                "left": row["left"],
                "top": row["top"],
                "width": row["width"],
                "height": row["height"] 
            },
            "offset": row["span"][0]
        }
        tokens.append(token_dict)
        return None
    
    global tokens

    #  Tokens creation from merged dataframe.
    merged_df.apply(lambda row: _create_token(row), axis=1)

    source = {
        "width": image_shape[1],
        "height": image_shape[0]
    }

    result = {
        "text": extracted_text,
        "tokens": tokens,
        "source": source
    }

    tokens = []
    return result


def debug_draw(result, image, save_path):
    """Debugging function. Draws recognized rectangles on an image"""
    
    color = (89, 28, 252)
    image_to_draw_at = image.copy()
    
    for token in result["tokens"]:
        x, y, w, h = token["position"]["left"], token["position"]["top"], \
                     token["position"]["width"], token["position"]["height"]
        cv2.rectangle(image_to_draw_at, (x, y), (x+w, y+h), color, 4)
    
    cv2.imwrite(save_path, image_to_draw_at)
    return save_path


def transform_coordinates(filtered_ocr_data, multiplier):
    """
    Function returns a dataframe with coordinates, that fit original image.
    """
    filtered_ocr_data["left"] = filtered_ocr_data["left"].apply(lambda c: int(c/multiplier))
    filtered_ocr_data["top"] = filtered_ocr_data["top"].apply(lambda c: int(c/multiplier))
    filtered_ocr_data["width"] = filtered_ocr_data["width"].apply(lambda c: int(c/multiplier))
    filtered_ocr_data["height"] = filtered_ocr_data["height"].apply(lambda c: int(c/multiplier))

    return filtered_ocr_data


def main_recognition(img_path):
    """
    Main function of recognition module.
    Goes throught all recognition steps and returning final result.
    """

    size = 4000
    lang = 'eng'
    config = '--psm 11'
    sep = ' '
    debug = True

    #  Image preparations.
    #  Interpolation, channels conversion from bgr to rgb to pass into tesseract.
    image, resized_image, multiplier, converted_image = prepare_image(img_path, size)

    #  Getting recognition data and removing unused data from tesseract output.
    ocr_data = recognize_image(converted_image, config, lang)
    filtered_ocr_data = filter_ocr_data(ocr_data)
    
    #  Coordinate transformation after resizing.
    #  Due to resize, it is needed to return back coords fitting original image.
    prepared_ocr_data = transform_coordinates(filtered_ocr_data, multiplier)
    #prepared_ocr_data = filtered_ocr_data

    #  Processing only text data from recognition.
    #  Affects only text information.
    extracted_text, text_df = process_text(prepared_ocr_data, sep)

    #  Processing extracted layout information (coordinates).
    layout_df = process_layout(prepared_ocr_data)

    #  Combined dataframe(text spans info + layout). In order to make it possible to parallel previous operations.
    concatenated_df = pd.concat([text_df, layout_df], axis=1)
    merged_df = concatenated_df.loc[:,~concatenated_df.columns.duplicated()]

    #  Result preparation.
    result = build_result(merged_df, extracted_text, image.shape)

    #  Debug depicting.
    if debug:
        save_path = str(Path("./").joinpath("debug_layout.jpg"))
        debug_draw(result, image, save_path)

    return result

# %%
img_path = "./pages/source/azb11c00.tif"
main_recognition(img_path)
# Out:
# {'text': 'wet fp) C BROWN & WILLIAMSON TOBACCO CORPORATION LETTER OF AUTHORIZATION July 26, 1985 Ms. Nancy Fletcher Kapuler Inc. 3436 N. Kennicott Avenue North Arlington Atrium Arlington Heights, IL 60004 Dear Nancy: This is your letter of authorization to conduct the ELI CUTTER Pack Color/Style Mix Evaluation for Brown & Williamson Tobacco Corporation. This letter constitutes a "Project Document” and is subject to all of the terms and conditions of that certain agreement between Brown & Williamson Tobacco Corporation and Kapuler, Inc., dated as of June 1, 1981, and together with said agreement constitutes the entire agreement for Kapuler, Inc. to conduct the ELI CUTTER Pack Color/Style Mix Evaluation for Brown & Williamson Tobacco Corporation, at the cost of $93,950. In the event of a conflict between the terms and conditions of said agreement and the terms and conditions of this document, the terms and conditions of this document shall control. Please assign Project No. 1985-97NP to this study and address all invoices to Ms. Sharon Willinger. Billing should be as follows: 1/3 of total upon completion. authorization, 1/3 upon completion of field work, and 1/3 upon study It is understood that Kapuler, Inc.\'s responsibilities will include discussion guide design and reproduction, respondent recruiting and interviewing, and a complete analysis and report of the results. Attached you will find a statement of the Study objectives, sample designation, and a discussion guide outline. Please sign below and return this document to Bruce Pellett at your earliest convenience. Thank you. 4y f (, if 7 af 4 f Hee ile o \\ 4 4 BROWN & WILLIAMSON REPRESENTATIVE DATE RESEARCH COMPANY REPRESENTATIVE DATE NAME OF RESEARCH COMPANY smc00009 Attachments KY 40232. (502) 568-7000 1500 BROWN & WILLIAMSON TONER, PO. BOX 35090, LOUISVILLE, 670542837 PRODUCED FROM B&W WEB SITE',
#  'tokens': [{'text': 'wet',
#    'position': {'left': 75, 'top': 15, 'width': 95, 'height': 46},
#    'offset': 0},
#   {'text': 'fp)',
#    'position': {'left': 2060, 'top': 44, 'width': 67, 'height': 29},
#    'offset': 4},
#   {'text': 'C',
#    'position': {'left': 667, 'top': 48, 'width': 42, 'height': 66},
#    'offset': 8},
#   {'text': 'BROWN',
#    'position': {'left': 300, 'top': 211, 'width': 385, 'height': 26},
#    'offset': 10},
#   {'text': '&',
#    'position': {'left': 413, 'top': 207, 'width': 41, 'height': 40},
#    'offset': 16},
#   {'text': 'WILLIAMSON',
#    'position': {'left': 457, 'top': 211, 'width': 229, 'height': 26},
#    'offset': 18},
#   {'text': 'TOBACCO',
#    'position': {'left': 299, 'top': 244, 'width': 154, 'height': 24},
#    'offset': 29},
#   {'text': 'CORPORATION',
#    'position': {'left': 466, 'top': 241, 'width': 236, 'height': 39},
#    'offset': 37},
#   {'text': 'LETTER',
#    'position': {'left': 854, 'top': 389, 'width': 130, 'height': 27},
#    'offset': 49},
#   {'text': 'OF',
#    'position': {'left': 1009, 'top': 392, 'width': 39, 'height': 25},
#    'offset': 56},
#   {'text': 'AUTHORIZATION',
#    'position': {'left': 1072, 'top': 392, 'width': 285, 'height': 29},
#    'offset': 59},
#   {'text': 'July',
#    'position': {'left': 260, 'top': 471, 'width': 85, 'height': 34},
#    'offset': 73},
#   {'text': '26,',
#    'position': {'left': 374, 'top': 470, 'width': 55, 'height': 33},
#    'offset': 78},
#   {'text': '1985',
#    'position': {'left': 463, 'top': 471, 'width': 81, 'height': 28},
#    'offset': 82},
#   {'text': 'Ms.',
#    'position': {'left': 257, 'top': 559, 'width': 61, 'height': 25},
#    'offset': 87},
#   {'text': 'Nancy',
#    'position': {'left': 347, 'top': 559, 'width': 108, 'height': 33},
#    'offset': 91},
#   {'text': 'Fletcher',
#    'position': {'left': 479, 'top': 559, 'width': 172, 'height': 28},
#    'offset': 97},
#   {'text': 'Kapuler',
#    'position': {'left': 259, 'top': 601, 'width': 151, 'height': 33},
#    'offset': 106},
#   {'text': 'Inc.',
#    'position': {'left': 437, 'top': 604, 'width': 79, 'height': 25},
#    'offset': 114},
#   {'text': '3436',
#    'position': {'left': 260, 'top': 642, 'width': 83, 'height': 29},
#    'offset': 119},
#   {'text': 'N.',
#    'position': {'left': 367, 'top': 647, 'width': 38, 'height': 25},
#    'offset': 124},
#   {'text': 'Kennicott',
#    'position': {'left': 434, 'top': 648, 'width': 192, 'height': 25},
#    'offset': 127},
#   {'text': 'Avenue',
#    'position': {'left': 652, 'top': 648, 'width': 129, 'height': 27},
#    'offset': 137},
#   {'text': 'North',
#    'position': {'left': 258, 'top': 689, 'width': 108, 'height': 26},
#    'offset': 144},
#   {'text': 'Arlington',
#    'position': {'left': 389, 'top': 689, 'width': 196, 'height': 35},
#    'offset': 150},
#   {'text': 'Atrium',
#    'position': {'left': 609, 'top': 693, 'width': 133, 'height': 25},
#    'offset': 160},
#   {'text': 'Arlington',
#    'position': {'left': 256, 'top': 731, 'width': 196, 'height': 35},
#    'offset': 167},
#   {'text': 'Heights,',
#    'position': {'left': 478, 'top': 734, 'width': 167, 'height': 34},
#    'offset': 177},
#   {'text': 'IL',
#    'position': {'left': 678, 'top': 737, 'width': 39, 'height': 26},
#    'offset': 186},
#   {'text': '60004',
#    'position': {'left': 765, 'top': 736, 'width': 105, 'height': 29},
#    'offset': 189},
#   {'text': 'Dear',
#    'position': {'left': 256, 'top': 820, 'width': 85, 'height': 27},
#    'offset': 195},
#   {'text': 'Nancy:',
#    'position': {'left': 366, 'top': 822, 'width': 122, 'height': 34},
#    'offset': 200},
#   {'text': 'This',
#    'position': {'left': 255, 'top': 908, 'width': 83, 'height': 27},
#    'offset': 207},
#   {'text': 'is',
#    'position': {'left': 367, 'top': 909, 'width': 38, 'height': 27},
#    'offset': 212},
#   {'text': 'your',
#    'position': {'left': 431, 'top': 918, 'width': 85, 'height': 26},
#    'offset': 215},
#   {'text': 'letter',
#    'position': {'left': 544, 'top': 911, 'width': 126, 'height': 28},
#    'offset': 220},
#   {'text': 'of',
#    'position': {'left': 696, 'top': 914, 'width': 38, 'height': 26},
#    'offset': 227},
#   {'text': 'authorization',
#    'position': {'left': 763, 'top': 915, 'width': 282, 'height': 29},
#    'offset': 230},
#   {'text': 'to',
#    'position': {'left': 1072, 'top': 922, 'width': 38, 'height': 22},
#    'offset': 244},
#   {'text': 'conduct',
#    'position': {'left': 1137, 'top': 919, 'width': 148, 'height': 29},
#    'offset': 247},
#   {'text': 'the',
#    'position': {'left': 1315, 'top': 922, 'width': 59, 'height': 26},
#    'offset': 255},
#   {'text': 'ELI',
#    'position': {'left': 1400, 'top': 923, 'width': 61, 'height': 25},
#    'offset': 259},
#   {'text': 'CUTTER',
#    'position': {'left': 1488, 'top': 924, 'width': 131, 'height': 27},
#    'offset': 263},
#   {'text': 'Pack',
#    'position': {'left': 1644, 'top': 926, 'width': 85, 'height': 28},
#    'offset': 270},
#   {'text': 'Color/Style',
#    'position': {'left': 1752, 'top': 925, 'width': 239, 'height': 37},
#    'offset': 275},
#   {'text': 'Mix',
#    'position': {'left': 253, 'top': 955, 'width': 66, 'height': 25},
#    'offset': 287},
#   {'text': 'Evaluation',
#    'position': {'left': 344, 'top': 956, 'width': 218, 'height': 28},
#    'offset': 291},
#   {'text': 'for',
#    'position': {'left': 589, 'top': 956, 'width': 59, 'height': 29},
#    'offset': 302},
#   {'text': 'Brown',
#    'position': {'left': 674, 'top': 959, 'width': 107, 'height': 26},
#    'offset': 306},
#   {'text': '&',
#    'position': {'left': 807, 'top': 962, 'width': 18, 'height': 24},
#    'offset': 312},
#   {'text': 'Williamson',
#    'position': {'left': 849, 'top': 960, 'width': 218, 'height': 29},
#    'offset': 314},
#   {'text': 'Tobacco',
#    'position': {'left': 1093, 'top': 963, 'width': 150, 'height': 29},
#    'offset': 325},
#   {'text': 'Corporation.',
#    'position': {'left': 1269, 'top': 963, 'width': 254, 'height': 41},
#    'offset': 333},
#   {'text': 'This',
#    'position': {'left': 255, 'top': 1042, 'width': 82, 'height': 28},
#    'offset': 346},
#   {'text': 'letter',
#    'position': {'left': 366, 'top': 1045, 'width': 126, 'height': 26},
#    'offset': 351},
#   {'text': 'constitutes',
#    'position': {'left': 520, 'top': 1048, 'width': 236, 'height': 27},
#    'offset': 358},
#   {'text': 'a',
#    'position': {'left': 783, 'top': 1056, 'width': 20, 'height': 20},
#    'offset': 370},
#   {'text': '"Project',
#    'position': {'left': 831, 'top': 1048, 'width': 168, 'height': 37},
#    'offset': 372},
#   {'text': 'Document”',
#    'position': {'left': 1025, 'top': 1053, 'width': 194, 'height': 27},
#    'offset': 381},
#   {'text': 'and',
#    'position': {'left': 1246, 'top': 1056, 'width': 62, 'height': 26},
#    'offset': 391},
#   {'text': 'is',
#    'position': {'left': 1335, 'top': 1056, 'width': 37, 'height': 27},
#    'offset': 395},
#   {'text': 'subject',
#    'position': {'left': 1402, 'top': 1057, 'width': 147, 'height': 35},
#    'offset': 398},
#   {'text': 'to',
#    'position': {'left': 1577, 'top': 1063, 'width': 38, 'height': 22},
#    'offset': 406},
#   {'text': 'all',
#    'position': {'left': 1642, 'top': 1060, 'width': 60, 'height': 27},
#    'offset': 409},
#   {'text': 'of',
#    'position': {'left': 1731, 'top': 1061, 'width': 37, 'height': 26},
#    'offset': 413},
#   {'text': 'the',
#    'position': {'left': 1798, 'top': 1062, 'width': 59, 'height': 26},
#    'offset': 416},
#   {'text': 'terms',
#    'position': {'left': 1887, 'top': 1067, 'width': 103, 'height': 23},
#    'offset': 420},
#   {'text': 'and',
#    'position': {'left': 255, 'top': 1089, 'width': 62, 'height': 26},
#    'offset': 426},
#   {'text': 'conditions',
#    'position': {'left': 344, 'top': 1089, 'width': 214, 'height': 29},
#    'offset': 430},
#   {'text': 'of',
#    'position': {'left': 586, 'top': 1093, 'width': 39, 'height': 26},
#    'offset': 441},
#   {'text': 'that',
#    'position': {'left': 652, 'top': 1093, 'width': 81, 'height': 27},
#    'offset': 444},
#   {'text': 'certain',
#    'position': {'left': 763, 'top': 1096, 'width': 149, 'height': 26},
#    'offset': 449},
#   {'text': 'agreement',
#    'position': {'left': 938, 'top': 1103, 'width': 194, 'height': 27},
#    'offset': 457},
#   {'text': 'between',
#    'position': {'left': 1158, 'top': 1098, 'width': 150, 'height': 28},
#    'offset': 467},
#   {'text': 'Brown',
#    'position': {'left': 1334, 'top': 1101, 'width': 107, 'height': 27},
#    'offset': 475},
#   {'text': '&',
#    'position': {'left': 1467, 'top': 1104, 'width': 16, 'height': 25},
#    'offset': 481},
#   {'text': 'Williamson',
#    'position': {'left': 1508, 'top': 1104, 'width': 218, 'height': 29},
#    'offset': 483},
#   {'text': 'Tobacco',
#    'position': {'left': 1752, 'top': 1107, 'width': 152, 'height': 26},
#    'offset': 494},
#   {'text': 'Corporation',
#    'position': {'left': 253, 'top': 1133, 'width': 240, 'height': 34},
#    'offset': 502},
#   {'text': 'and',
#    'position': {'left': 519, 'top': 1135, 'width': 61, 'height': 27},
#    'offset': 514},
#   {'text': 'Kapuler,',
#    'position': {'left': 607, 'top': 1137, 'width': 170, 'height': 33},
#    'offset': 518},
#   {'text': 'Inc.,',
#    'position': {'left': 806, 'top': 1140, 'width': 100, 'height': 33},
#    'offset': 527},
#   {'text': 'dated',
#    'position': {'left': 937, 'top': 1140, 'width': 104, 'height': 28},
#    'offset': 533},
#   {'text': 'as',
#    'position': {'left': 1069, 'top': 1149, 'width': 39, 'height': 20},
#    'offset': 539},
#   {'text': 'of',
#    'position': {'left': 1135, 'top': 1142, 'width': 39, 'height': 27},
#    'offset': 542},
#   {'text': 'June',
#    'position': {'left': 1201, 'top': 1145, 'width': 84, 'height': 26},
#    'offset': 545},
#   {'text': '1,',
#    'position': {'left': 1316, 'top': 1145, 'width': 31, 'height': 33},
#    'offset': 550},
#   {'text': '1981,',
#    'position': {'left': 1382, 'top': 1145, 'width': 96, 'height': 35},
#    'offset': 553},
#   {'text': 'and',
#    'position': {'left': 1510, 'top': 1148, 'width': 61, 'height': 27},
#    'offset': 559},
#   {'text': 'together',
#    'position': {'left': 1599, 'top': 1149, 'width': 172, 'height': 35},
#    'offset': 563},
#   {'text': 'with',
#    'position': {'left': 1795, 'top': 1152, 'width': 87, 'height': 25},
#    'offset': 572},
#   {'text': 'said',
#    'position': {'left': 1907, 'top': 1152, 'width': 84, 'height': 27},
#    'offset': 577},
#   {'text': 'agreement',
#    'position': {'left': 253, 'top': 1185, 'width': 194, 'height': 26},
#    'offset': 582},
#   {'text': 'constitutes',
#    'position': {'left': 476, 'top': 1182, 'width': 235, 'height': 27},
#    'offset': 592},
#   {'text': 'the',
#    'position': {'left': 742, 'top': 1185, 'width': 59, 'height': 25},
#    'offset': 604},
#   {'text': 'entire',
#    'position': {'left': 828, 'top': 1185, 'width': 128, 'height': 26},
#    'offset': 608},
#   {'text': 'agreement',
#    'position': {'left': 982, 'top': 1193, 'width': 192, 'height': 28},
#    'offset': 615},
#   {'text': 'for',
#    'position': {'left': 1203, 'top': 1189, 'width': 60, 'height': 26},
#    'offset': 625},
#   {'text': 'Kapuler,',
#    'position': {'left': 1289, 'top': 1190, 'width': 168, 'height': 35},
#    'offset': 629},
#   {'text': 'Inc.',
#    'position': {'left': 1490, 'top': 1193, 'width': 77, 'height': 28},
#    'offset': 638},
#   {'text': 'to',
#    'position': {'left': 1599, 'top': 1198, 'width': 39, 'height': 23},
#    'offset': 643},
#   {'text': 'conduct',
#    'position': {'left': 1665, 'top': 1196, 'width': 148, 'height': 27},
#    'offset': 646},
#   {'text': 'the',
#    'position': {'left': 1843, 'top': 1197, 'width': 59, 'height': 26},
#    'offset': 654},
#   {'text': 'ELI',
#    'position': {'left': 252, 'top': 1222, 'width': 62, 'height': 25},
#    'offset': 658},
#   {'text': 'CUTTER',
#    'position': {'left': 341, 'top': 1223, 'width': 129, 'height': 28},
#    'offset': 662},
#   {'text': 'Pack',
#    'position': {'left': 497, 'top': 1226, 'width': 85, 'height': 26},
#    'offset': 669},
#   {'text': 'Color/Style',
#    'position': {'left': 605, 'top': 1223, 'width': 239, 'height': 39},
#    'offset': 674},
#   {'text': 'Mix',
#    'position': {'left': 869, 'top': 1230, 'width': 64, 'height': 25},
#    'offset': 686},
#   {'text': 'Evaluation',
#    'position': {'left': 958, 'top': 1230, 'width': 216, 'height': 29},
#    'offset': 690},
#   {'text': 'for',
#    'position': {'left': 1202, 'top': 1233, 'width': 60, 'height': 27},
#    'offset': 701},
#   {'text': 'Brown',
#    'position': {'left': 1288, 'top': 1235, 'width': 107, 'height': 27},
#    'offset': 705},
#   {'text': '&',
#    'position': {'left': 1423, 'top': 1237, 'width': 16, 'height': 25},
#    'offset': 711},
#   {'text': 'Williamson',
#    'position': {'left': 1464, 'top': 1237, 'width': 218, 'height': 29},
#    'offset': 713},
#   {'text': 'Tobacco',
#    'position': {'left': 1707, 'top': 1236, 'width': 151, 'height': 43},
#    'offset': 724},
#   {'text': 'Corporation,',
#    'position': {'left': 253, 'top': 1267, 'width': 257, 'height': 36},
#    'offset': 732},
#   {'text': 'at',
#    'position': {'left': 540, 'top': 1274, 'width': 38, 'height': 22},
#    'offset': 745},
#   {'text': 'the',
#    'position': {'left': 607, 'top': 1271, 'width': 59, 'height': 27},
#    'offset': 748},
#   {'text': 'cost',
#    'position': {'left': 694, 'top': 1277, 'width': 82, 'height': 22},
#    'offset': 752},
#   {'text': 'of',
#    'position': {'left': 804, 'top': 1274, 'width': 39, 'height': 26},
#    'offset': 757},
#   {'text': '$93,950.',
#    'position': {'left': 872, 'top': 1271, 'width': 166, 'height': 37},
#    'offset': 760},
#   {'text': 'In',
#    'position': {'left': 1093, 'top': 1277, 'width': 38, 'height': 26},
#    'offset': 769},
#   {'text': 'the',
#    'position': {'left': 1157, 'top': 1276, 'width': 59, 'height': 29},
#    'offset': 772},
#   {'text': 'event',
#    'position': {'left': 1245, 'top': 1285, 'width': 104, 'height': 22},
#    'offset': 776},
#   {'text': 'of',
#    'position': {'left': 1377, 'top': 1281, 'width': 39, 'height': 26},
#    'offset': 782},
#   {'text': 'a',
#    'position': {'left': 1442, 'top': 1289, 'width': 18, 'height': 18},
#    'offset': 785},
#   {'text': 'conflict',
#    'position': {'left': 1488, 'top': 1282, 'width': 170, 'height': 28},
#    'offset': 787},
#   {'text': 'between',
#    'position': {'left': 1684, 'top': 1285, 'width': 151, 'height': 27},
#    'offset': 796},
#   {'text': 'the',
#    'position': {'left': 1864, 'top': 1286, 'width': 59, 'height': 28},
#    'offset': 804},
#   {'text': 'terms',
#    'position': {'left': 255, 'top': 1315, 'width': 104, 'height': 25},
#    'offset': 808},
#   {'text': 'and',
#    'position': {'left': 386, 'top': 1315, 'width': 61, 'height': 25},
#    'offset': 814},
#   {'text': 'conditions',
#    'position': {'left': 474, 'top': 1315, 'width': 214, 'height': 29},
#    'offset': 818},
#   {'text': 'of',
#    'position': {'left': 716, 'top': 1318, 'width': 40, 'height': 27},
#    'offset': 829},
#   {'text': 'said',
#    'position': {'left': 785, 'top': 1319, 'width': 81, 'height': 26},
#    'offset': 832},
#   {'text': 'agreement',
#    'position': {'left': 893, 'top': 1326, 'width': 192, 'height': 27},
#    'offset': 837},
#   {'text': 'and',
#    'position': {'left': 1111, 'top': 1323, 'width': 63, 'height': 26},
#    'offset': 847},
#   {'text': 'the',
#    'position': {'left': 1202, 'top': 1323, 'width': 60, 'height': 28},
#    'offset': 851},
#   {'text': 'terms',
#    'position': {'left': 1291, 'top': 1328, 'width': 103, 'height': 24},
#    'offset': 855},
#   {'text': 'and',
#    'position': {'left': 1423, 'top': 1326, 'width': 61, 'height': 26},
#    'offset': 861},
#   {'text': 'conditions',
#    'position': {'left': 1512, 'top': 1329, 'width': 212, 'height': 27},
#    'offset': 865},
#   {'text': 'of',
#    'position': {'left': 1752, 'top': 1330, 'width': 39, 'height': 25},
#    'offset': 876},
#   {'text': 'this',
#    'position': {'left': 1821, 'top': 1330, 'width': 80, 'height': 27},
#    'offset': 879},
#   {'text': 'document,',
#    'position': {'left': 252, 'top': 1356, 'width': 190, 'height': 36},
#    'offset': 884},
#   {'text': 'the',
#    'position': {'left': 474, 'top': 1359, 'width': 59, 'height': 26},
#    'offset': 894},
#   {'text': 'terms',
#    'position': {'left': 564, 'top': 1364, 'width': 102, 'height': 23},
#    'offset': 898},
#   {'text': 'and',
#    'position': {'left': 693, 'top': 1360, 'width': 63, 'height': 28},
#    'offset': 904},
#   {'text': 'conditions',
#    'position': {'left': 781, 'top': 1363, 'width': 214, 'height': 29},
#    'offset': 908},
#   {'text': 'of',
#    'position': {'left': 1023, 'top': 1364, 'width': 40, 'height': 27},
#    'offset': 919},
#   {'text': 'this',
#    'position': {'left': 1092, 'top': 1366, 'width': 80, 'height': 26},
#    'offset': 922},
#   {'text': 'document',
#    'position': {'left': 1200, 'top': 1367, 'width': 170, 'height': 29},
#    'offset': 927},
#   {'text': 'shall',
#    'position': {'left': 1400, 'top': 1370, 'width': 103, 'height': 29},
#    'offset': 936},
#   {'text': 'control.',
#    'position': {'left': 1532, 'top': 1370, 'width': 166, 'height': 40},
#    'offset': 942},
#   {'text': 'Please',
#    'position': {'left': 1751, 'top': 1374, 'width': 127, 'height': 28},
#    'offset': 951},
#   {'text': 'assign',
#    'position': {'left': 252, 'top': 1401, 'width': 129, 'height': 34},
#    'offset': 958},
#   {'text': 'Project',
#    'position': {'left': 407, 'top': 1404, 'width': 149, 'height': 33},
#    'offset': 965},
#   {'text': 'No.',
#    'position': {'left': 581, 'top': 1405, 'width': 59, 'height': 26},
#    'offset': 973},
#   {'text': '1985-97NP',
#    'position': {'left': 674, 'top': 1405, 'width': 192, 'height': 28},
#    'offset': 977},
#   {'text': 'to',
#    'position': {'left': 893, 'top': 1412, 'width': 40, 'height': 23},
#    'offset': 987},
#   {'text': 'this',
#    'position': {'left': 959, 'top': 1408, 'width': 81, 'height': 28},
#    'offset': 990},
#   {'text': 'study',
#    'position': {'left': 1068, 'top': 1411, 'width': 107, 'height': 34},
#    'offset': 995},
#   {'text': 'and',
#    'position': {'left': 1201, 'top': 1412, 'width': 61, 'height': 25},
#    'offset': 1001},
#   {'text': 'address',
#    'position': {'left': 1288, 'top': 1413, 'width': 150, 'height': 28},
#    'offset': 1005},
#   {'text': 'all',
#    'position': {'left': 1465, 'top': 1415, 'width': 62, 'height': 27},
#    'offset': 1013},
#   {'text': 'invoices',
#    'position': {'left': 1553, 'top': 1416, 'width': 170, 'height': 29},
#    'offset': 1017},
#   {'text': 'to',
#    'position': {'left': 1753, 'top': 1423, 'width': 37, 'height': 22},
#    'offset': 1026},
#   {'text': 'Ms.',
#    'position': {'left': 251, 'top': 1445, 'width': 61, 'height': 25},
#    'offset': 1029},
#   {'text': 'Sharon',
#    'position': {'left': 341, 'top': 1445, 'width': 127, 'height': 28},
#    'offset': 1033},
#   {'text': 'Willinger.',
#    'position': {'left': 492, 'top': 1449, 'width': 214, 'height': 35},
#    'offset': 1040},
#   {'text': 'Billing',
#    'position': {'left': 757, 'top': 1452, 'width': 151, 'height': 33},
#    'offset': 1051},
#   {'text': 'should',
#    'position': {'left': 935, 'top': 1452, 'width': 128, 'height': 28},
#    'offset': 1059},
#   {'text': 'be',
#    'position': {'left': 1089, 'top': 1453, 'width': 38, 'height': 28},
#    'offset': 1066},
#   {'text': 'as',
#    'position': {'left': 1156, 'top': 1463, 'width': 37, 'height': 19},
#    'offset': 1069},
#   {'text': 'follows:',
#    'position': {'left': 1222, 'top': 1456, 'width': 166, 'height': 29},
#    'offset': 1072},
#   {'text': '1/3',
#    'position': {'left': 1446, 'top': 1456, 'width': 58, 'height': 33},
#    'offset': 1081},
#   {'text': 'of',
#    'position': {'left': 1531, 'top': 1460, 'width': 37, 'height': 27},
#    'offset': 1085},
#   {'text': 'total',
#    'position': {'left': 1598, 'top': 1462, 'width': 103, 'height': 26},
#    'offset': 1088},
#   {'text': 'upon',
#    'position': {'left': 1727, 'top': 1471, 'width': 85, 'height': 25},
#    'offset': 1094},
#   {'text': 'completion.',
#    'position': {'left': 252, 'top': 1534, 'width': 233, 'height': 33},
#    'offset': 1099},
#   {'text': 'authorization,',
#    'position': {'left': 252, 'top': 1489, 'width': 299, 'height': 36},
#    'offset': 1111},
#   {'text': '1/3',
#    'position': {'left': 585, 'top': 1490, 'width': 59, 'height': 32},
#    'offset': 1126},
#   {'text': 'upon',
#    'position': {'left': 670, 'top': 1502, 'width': 85, 'height': 26},
#    'offset': 1130},
#   {'text': 'completion',
#    'position': {'left': 781, 'top': 1496, 'width': 216, 'height': 33},
#    'offset': 1135},
#   {'text': 'of',
#    'position': {'left': 1024, 'top': 1498, 'width': 39, 'height': 26},
#    'offset': 1146},
#   {'text': 'field',
#    'position': {'left': 1091, 'top': 1498, 'width': 103, 'height': 28},
#    'offset': 1149},
#   {'text': 'work,',
#    'position': {'left': 1219, 'top': 1500, 'width': 103, 'height': 35},
#    'offset': 1155},
#   {'text': 'and',
#    'position': {'left': 1354, 'top': 1503, 'width': 61, 'height': 26},
#    'offset': 1161},
#   {'text': '1/3',
#    'position': {'left': 1446, 'top': 1500, 'width': 59, 'height': 33},
#    'offset': 1165},
#   {'text': 'upon',
#    'position': {'left': 1530, 'top': 1512, 'width': 85, 'height': 25},
#    'offset': 1169},
#   {'text': 'study',
#    'position': {'left': 1642, 'top': 1507, 'width': 104, 'height': 33},
#    'offset': 1174},
#   {'text': 'It',
#    'position': {'left': 252, 'top': 1620, 'width': 37, 'height': 26},
#    'offset': 1180},
#   {'text': 'is',
#    'position': {'left': 318, 'top': 1620, 'width': 37, 'height': 26},
#    'offset': 1183},
#   {'text': 'understood',
#    'position': {'left': 382, 'top': 1622, 'width': 214, 'height': 29},
#    'offset': 1186},
#   {'text': 'that',
#    'position': {'left': 627, 'top': 1624, 'width': 80, 'height': 27},
#    'offset': 1197},
#   {'text': 'Kapuler,',
#    'position': {'left': 734, 'top': 1626, 'width': 169, 'height': 33},
#    'offset': 1202},
#   {'text': "Inc.'s",
#    'position': {'left': 935, 'top': 1627, 'width': 126, 'height': 28},
#    'offset': 1211},
#   {'text': 'responsibilities',
#    'position': {'left': 1087, 'top': 1631, 'width': 348, 'height': 32},
#    'offset': 1218},
#   {'text': 'will',
#    'position': {'left': 1461, 'top': 1635, 'width': 84, 'height': 26},
#    'offset': 1235},
#   {'text': 'include',
#    'position': {'left': 1575, 'top': 1637, 'width': 148, 'height': 27},
#    'offset': 1240},
#   {'text': 'discussion',
#    'position': {'left': 1749, 'top': 1638, 'width': 217, 'height': 29},
#    'offset': 1248},
#   {'text': 'guide',
#    'position': {'left': 248, 'top': 1664, 'width': 109, 'height': 32},
#    'offset': 1259},
#   {'text': 'design',
#    'position': {'left': 382, 'top': 1665, 'width': 129, 'height': 34},
#    'offset': 1265},
#   {'text': 'and',
#    'position': {'left': 537, 'top': 1667, 'width': 61, 'height': 26},
#    'offset': 1272},
#   {'text': 'reproduction,',
#    'position': {'left': 626, 'top': 1670, 'width': 277, 'height': 34},
#    'offset': 1276},
#   {'text': 'respondent',
#    'position': {'left': 934, 'top': 1674, 'width': 214, 'height': 30},
#    'offset': 1290},
#   {'text': 'recruiting',
#    'position': {'left': 1177, 'top': 1676, 'width': 217, 'height': 35},
#    'offset': 1301},
#   {'text': 'and',
#    'position': {'left': 1420, 'top': 1678, 'width': 62, 'height': 25},
#    'offset': 1312},
#   {'text': 'interviewing,',
#    'position': {'left': 1508, 'top': 1681, 'width': 277, 'height': 33},
#    'offset': 1316},
#   {'text': 'and',
#    'position': {'left': 1816, 'top': 1682, 'width': 63, 'height': 25},
#    'offset': 1330},
#   {'text': 'a',
#    'position': {'left': 1905, 'top': 1690, 'width': 16, 'height': 18},
#    'offset': 1334},
#   {'text': 'complete',
#    'position': {'left': 252, 'top': 1708, 'width': 169, 'height': 33},
#    'offset': 1336},
#   {'text': 'analysis',
#    'position': {'left': 448, 'top': 1711, 'width': 171, 'height': 33},
#    'offset': 1345},
#   {'text': 'and',
#    'position': {'left': 644, 'top': 1712, 'width': 63, 'height': 25},
#    'offset': 1354},
#   {'text': 'report',
#    'position': {'left': 734, 'top': 1719, 'width': 126, 'height': 27},
#    'offset': 1358},
#   {'text': 'of',
#    'position': {'left': 889, 'top': 1715, 'width': 38, 'height': 26},
#    'offset': 1365},
#   {'text': 'the',
#    'position': {'left': 956, 'top': 1715, 'width': 60, 'height': 26},
#    'offset': 1368},
#   {'text': 'results.',
#    'position': {'left': 1042, 'top': 1719, 'width': 169, 'height': 25},
#    'offset': 1372},
#   {'text': 'Attached',
#    'position': {'left': 248, 'top': 1794, 'width': 173, 'height': 28},
#    'offset': 1381},
#   {'text': 'you',
#    'position': {'left': 446, 'top': 1804, 'width': 65, 'height': 25},
#    'offset': 1390},
#   {'text': 'will',
#    'position': {'left': 533, 'top': 1797, 'width': 85, 'height': 28},
#    'offset': 1394},
#   {'text': 'find',
#    'position': {'left': 648, 'top': 1800, 'width': 82, 'height': 26},
#    'offset': 1399},
#   {'text': 'a',
#    'position': {'left': 756, 'top': 1808, 'width': 18, 'height': 18},
#    'offset': 1404},
#   {'text': 'statement',
#    'position': {'left': 804, 'top': 1805, 'width': 190, 'height': 24},
#    'offset': 1406},
#   {'text': 'of',
#    'position': {'left': 1021, 'top': 1804, 'width': 40, 'height': 26},
#    'offset': 1416},
#   {'text': 'the',
#    'position': {'left': 1089, 'top': 1804, 'width': 59, 'height': 26},
#    'offset': 1419},
#   {'text': 'Study',
#    'position': {'left': 1177, 'top': 1807, 'width': 106, 'height': 33},
#    'offset': 1423},
#   {'text': 'objectives,',
#    'position': {'left': 1308, 'top': 1808, 'width': 233, 'height': 34},
#    'offset': 1429},
#   {'text': 'sample',
#    'position': {'left': 1575, 'top': 1812, 'width': 126, 'height': 32},
#    'offset': 1441},
#   {'text': 'designation,',
#    'position': {'left': 1728, 'top': 1812, 'width': 255, 'height': 35},
#    'offset': 1448},
#   {'text': 'and',
#    'position': {'left': 248, 'top': 1838, 'width': 63, 'height': 25},
#    'offset': 1461},
#   {'text': 'a',
#    'position': {'left': 337, 'top': 1845, 'width': 19, 'height': 20},
#    'offset': 1465},
#   {'text': 'discussion',
#    'position': {'left': 381, 'top': 1838, 'width': 215, 'height': 29},
#    'offset': 1467},
#   {'text': 'guide',
#    'position': {'left': 622, 'top': 1842, 'width': 106, 'height': 34},
#    'offset': 1478},
#   {'text': 'outline.',
#    'position': {'left': 756, 'top': 1845, 'width': 169, 'height': 26},
#    'offset': 1484},
#   {'text': 'Please',
#    'position': {'left': 248, 'top': 1923, 'width': 126, 'height': 28},
#    'offset': 1493},
#   {'text': 'sign',
#    'position': {'left': 403, 'top': 1927, 'width': 82, 'height': 33},
#    'offset': 1500},
#   {'text': 'below',
#    'position': {'left': 512, 'top': 1927, 'width': 110, 'height': 29},
#    'offset': 1505},
#   {'text': 'and',
#    'position': {'left': 644, 'top': 1930, 'width': 62, 'height': 26},
#    'offset': 1511},
#   {'text': 'return',
#    'position': {'left': 733, 'top': 1934, 'width': 127, 'height': 22},
#    'offset': 1515},
#   {'text': 'this',
#    'position': {'left': 889, 'top': 1933, 'width': 81, 'height': 26},
#    'offset': 1522},
#   {'text': 'document',
#    'position': {'left': 996, 'top': 1934, 'width': 171, 'height': 27},
#    'offset': 1527},
#   {'text': 'to',
#    'position': {'left': 1198, 'top': 1941, 'width': 37, 'height': 22},
#    'offset': 1536},
#   {'text': 'Bruce',
#    'position': {'left': 1262, 'top': 1938, 'width': 106, 'height': 25},
#    'offset': 1539},
#   {'text': 'Pellett',
#    'position': {'left': 1395, 'top': 1939, 'width': 149, 'height': 27},
#    'offset': 1545},
#   {'text': 'at',
#    'position': {'left': 1570, 'top': 1946, 'width': 39, 'height': 21},
#    'offset': 1553},
#   {'text': 'your',
#    'position': {'left': 1637, 'top': 1950, 'width': 84, 'height': 25},
#    'offset': 1556},
#   {'text': 'earliest',
#    'position': {'left': 1748, 'top': 1943, 'width': 171, 'height': 28},
#    'offset': 1561},
#   {'text': 'convenience.',
#    'position': {'left': 249, 'top': 1966, 'width': 253, 'height': 48},
#    'offset': 1570},
#   {'text': 'Thank',
#    'position': {'left': 556, 'top': 1969, 'width': 107, 'height': 52},
#    'offset': 1583},
#   {'text': 'you.',
#    'position': {'left': 689, 'top': 1980, 'width': 81, 'height': 26},
#    'offset': 1589},
#   {'text': '4y',
#    'position': {'left': 321, 'top': 2006, 'width': 19, 'height': 21},
#    'offset': 1594},
#   {'text': 'f',
#    'position': {'left': 1599, 'top': 2023, 'width': 7, 'height': 7},
#    'offset': 1597},
#   {'text': '(,',
#    'position': {'left': 249, 'top': 2052, 'width': 41, 'height': 25},
#    'offset': 1599},
#   {'text': 'if',
#    'position': {'left': 1515, 'top': 2086, 'width': 45, 'height': 22},
#    'offset': 1602},
#   {'text': '7',
#    'position': {'left': 1525, 'top': 2076, 'width': 13, 'height': 14},
#    'offset': 1605},
#   {'text': 'af',
#    'position': {'left': 1607, 'top': 2086, 'width': 64, 'height': 29},
#    'offset': 1607},
#   {'text': '4',
#    'position': {'left': 1718, 'top': 2084, 'width': 19, 'height': 20},
#    'offset': 1610},
#   {'text': 'f',
#    'position': {'left': 1747, 'top': 2100, 'width': 11, 'height': 14},
#    'offset': 1612},
#   {'text': 'Hee',
#    'position': {'left': 330, 'top': 2075, 'width': 92, 'height': 58},
#    'offset': 1614},
#   {'text': 'ile',
#    'position': {'left': 479, 'top': 2009, 'width': 261, 'height': 125},
#    'offset': 1618},
#   {'text': 'o',
#    'position': {'left': 1588, 'top': 2123, 'width': 17, 'height': 11},
#    'offset': 1622},
#   {'text': '\\',
#    'position': {'left': 1652, 'top': 2123, 'width': 5, 'height': 10},
#    'offset': 1624},
#   {'text': '4',
#    'position': {'left': 1702, 'top': 2105, 'width': 15, 'height': 16},
#    'offset': 1626},
#   {'text': '4',
#    'position': {'left': 1801, 'top': 2102, 'width': 73, 'height': 31},
#    'offset': 1628},
#   {'text': 'BROWN',
#    'position': {'left': 245, 'top': 2145, 'width': 109, 'height': 25},
#    'offset': 1630},
#   {'text': '&',
#    'position': {'left': 379, 'top': 2147, 'width': 18, 'height': 25},
#    'offset': 1636},
#   {'text': 'WILLIAMSON',
#    'position': {'left': 420, 'top': 2149, 'width': 221, 'height': 27},
#    'offset': 1638},
#   {'text': 'REPRESENTATIVE',
#    'position': {'left': 665, 'top': 2152, 'width': 305, 'height': 27},
#    'offset': 1649},
#   {'text': 'DATE',
#    'position': {'left': 1591, 'top': 2164, 'width': 85, 'height': 25},
#    'offset': 1664},
#   {'text': 'RESEARCH',
#    'position': {'left': 244, 'top': 2279, 'width': 174, 'height': 28},
#    'offset': 1669},
#   {'text': 'COMPANY',
#    'position': {'left': 444, 'top': 2282, 'width': 152, 'height': 26},
#    'offset': 1678},
#   {'text': 'REPRESENTATIVE',
#    'position': {'left': 620, 'top': 2285, 'width': 305, 'height': 26},
#    'offset': 1686},
#   {'text': 'DATE',
#    'position': {'left': 1591, 'top': 2297, 'width': 85, 'height': 25},
#    'offset': 1701},
#   {'text': 'NAME',
#    'position': {'left': 244, 'top': 2410, 'width': 85, 'height': 27},
#    'offset': 1706},
#   {'text': 'OF',
#    'position': {'left': 355, 'top': 2413, 'width': 40, 'height': 25},
#    'offset': 1711},
#   {'text': 'RESEARCH',
#    'position': {'left': 420, 'top': 2416, 'width': 175, 'height': 25},
#    'offset': 1714},
#   {'text': 'COMPANY',
#    'position': {'left': 619, 'top': 2416, 'width': 151, 'height': 25},
#    'offset': 1723},
#   {'text': 'smc00009',
#    'position': {'left': 244, 'top': 2542, 'width': 170, 'height': 29},
#    'offset': 1731},
#   {'text': 'Attachments',
#    'position': {'left': 241, 'top': 2586, 'width': 239, 'height': 29},
#    'offset': 1740},
#   {'text': 'KY',
#    'position': {'left': 1109, 'top': 2817, 'width': 31, 'height': 19},
#    'offset': 1752},
#   {'text': '40232.',
#    'position': {'left': 1152, 'top': 2820, 'width': 72, 'height': 17},
#    'offset': 1755},
#   {'text': '(502)',
#    'position': {'left': 1235, 'top': 2821, 'width': 54, 'height': 20},
#    'offset': 1762},
#   {'text': '568-7000',
#    'position': {'left': 1301, 'top': 2821, 'width': 99, 'height': 18},
#    'offset': 1768},
#   {'text': '1500',
#    'position': {'left': 285, 'top': 2812, 'width': 48, 'height': 17},
#    'offset': 1777},
#   {'text': 'BROWN',
#    'position': {'left': 344, 'top': 2812, 'width': 91, 'height': 18},
#    'offset': 1782},
#   {'text': '&',
#    'position': {'left': 444, 'top': 2813, 'width': 14, 'height': 18},
#    'offset': 1788},
#   {'text': 'WILLIAMSON',
#    'position': {'left': 470, 'top': 2809, 'width': 166, 'height': 38},
#    'offset': 1790},
#   {'text': 'TONER,',
#    'position': {'left': 629, 'top': 2810, 'width': 113, 'height': 56},
#    'offset': 1801},
#   {'text': 'PO.',
#    'position': {'left': 754, 'top': 2815, 'width': 37, 'height': 18},
#    'offset': 1808},
#   {'text': 'BOX',
#    'position': {'left': 804, 'top': 2816, 'width': 48, 'height': 18},
#    'offset': 1812},
#   {'text': '35090,',
#    'position': {'left': 864, 'top': 2819, 'width': 69, 'height': 17},
#    'offset': 1816},
#   {'text': 'LOUISVILLE,',
#    'position': {'left': 946, 'top': 2811, 'width': 154, 'height': 25},
#    'offset': 1823},
#   {'text': '670542837',
#    'position': {'left': 6, 'top': 3008, 'width': 239, 'height': 29},
#    'offset': 1835},
#   {'text': 'PRODUCED',
#    'position': {'left': 4, 'top': 3060, 'width': 217, 'height': 27},
#    'offset': 1845},
#   {'text': 'FROM',
#    'position': {'left': 256, 'top': 3060, 'width': 106, 'height': 27},
#    'offset': 1854},
#   {'text': 'B&W',
#    'position': {'left': 394, 'top': 3060, 'width': 81, 'height': 27},
#    'offset': 1859},
#   {'text': 'WEB',
#    'position': {'left': 504, 'top': 3060, 'width': 80, 'height': 26},
#    'offset': 1863},
#   {'text': 'SITE',
#    'position': {'left': 619, 'top': 3060, 'width': 105, 'height': 27},
#    'offset': 1867}],
#  'source': {'width': 2400, 'height': 3150}}
